# %%
# 좌측 extension에서 sqlite / sqlite viewer install

# %%
import sqlite3

conn = sqlite3.connect('./data/db.sqlite3')
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")

tables = cursor.fetchall()
for table in tables:
    print(table[0])
# Out:
# django_migrations
# sqlite_sequence
# auth_group_permissions
# auth_user_groups
# auth_user_user_permissions
# django_admin_log
# django_content_type
# auth_permission
# auth_group
# auth_user
# django_session
# soolpan_user
# Comments_data
# favorite_database
# img_blog
# traditional_liq

# %%
# 각 테이블의 컬럼 이름과 데이터 타입 출력
for table in tables:
    table_name = table[0]
    print(f"Table Name: {table_name}")
    
    # 테이블 구조 출력
    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()
    
    print("  Column Names and Data Types:")
    for column in columns:
        column_name = column[1]
        data_type = column[2]
        print(f"    Column: {column_name}, Type: {data_type}")
# Out:
# Table Name: django_migrations
#   Column Names and Data Types:
#     Column: id, Type: INTEGER
#     Column: app, Type: varchar(255)
#     Column: name, Type: varchar(255)
#     Column: applied, Type: datetime
# Table Name: sqlite_sequence
#   Column Names and Data Types:
#     Column: name, Type:
#     Column: seq, Type:
# Table Name: auth_group_permissions
#   Column Names and Data Types:
#     Column: id, Type: INTEGER
#     Column: group_id, Type: INTEGER
#     Column: permission_id, Type: INTEGER
# Table Name: auth_user_groups
#   Column Names and Data Types:
#     Column: id, Type: INTEGER
#     Column: user_id, Type: INTEGER
#     Column: group_id, Type: INTEGER
# Table Name: auth_user_user_permissions
#   Column Names and Data Types:
#     Column: id, Type: INTEGER
#     Column: user_id, Type: INTEGER
#     Column: permission_id, Type: INTEGER
# Table Name: django_admin_log
#   Column Names and Data Types:
#     Column: id, Type: INTEGER
#     Column: object_id, Type: TEXT
# ...

# %%
# 각 테이블의 컬럼 이름, 데이터 타입, 프라이머리 키 설정 여부 출력
for table in tables:
    table_name = table[0]
    print(f"Table Name: {table_name}")
    
    # 테이블 구조 출력
    cursor.execute(f"PRAGMA table_info({table_name});")
    columns = cursor.fetchall()
    
    # print("  Column Names, Data Types, and Primary Key:")
    for column in columns:
        column_name = column[1]
        data_type = column[2]
        is_primary_key = "PRIMARY KEY" if column[5] == 1 else ""
        print(f"    Column: {column_name}, Type: {data_type}, {is_primary_key}")
# Out:
# Table Name: django_migrations
#     Column: id, Type: INTEGER, PRIMARY KEY
#     Column: app, Type: varchar(255),
#     Column: name, Type: varchar(255),
#     Column: applied, Type: datetime,
# Table Name: sqlite_sequence
#     Column: name, Type: ,
#     Column: seq, Type: ,
# Table Name: auth_group_permissions
#     Column: id, Type: INTEGER, PRIMARY KEY
#     Column: group_id, Type: INTEGER,
#     Column: permission_id, Type: INTEGER,
# Table Name: auth_user_groups
#     Column: id, Type: INTEGER, PRIMARY KEY
#     Column: user_id, Type: INTEGER,
#     Column: group_id, Type: INTEGER,
# Table Name: auth_user_user_permissions
#     Column: id, Type: INTEGER, PRIMARY KEY
#     Column: user_id, Type: INTEGER,
#     Column: permission_id, Type: INTEGER,
# Table Name: django_admin_log
#     Column: id, Type: INTEGER, PRIMARY KEY
#     Column: object_id, Type: TEXT,
#     Column: object_repr, Type: varchar(200),
#     Column: action_flag, Type: smallint unsigned,
# ...
